# %%
'''Q1. Explain why we have to use the Exception class while creating a Custom Exception.
Note: Here Exception class refers to the base class for all the exceptions.
- We need to use the Exception class while creating a custom exception because in python all exceptions must be 
instances of a class that derives from the BaseException(it is base class for all exceptions in python. It can not be directly
inherited by the user defined classes.'''
# Out:
# 'Q1. Explain why we have to use the Exception class while creating a Custom Exception.\nNote: Here Exception class refers to the base class for all the exceptions.\n- We need to use the Exception class while creating a custom exception because in python all exceptions must be \ninstances of a class that derives from the BaseException(it is base class for all exceptions in python. It can not be directly\ninherited by the user defined classes.'

# %%
'''Q2. Write a python program to print Python Exception Hierarchy.'''
dir(Exception)
# Out:
# ['__cause__',
#  '__class__',
#  '__context__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__suppress_context__',
#  '__traceback__',
#  'args',
#  'with_traceback']

# %%
import inspect

# %%
def tree_class(cls, ind=0):
    print('-' * ind , cls.__name__)
    for i in cls.__subclasses__():
          tree_class(i, ind + 3)
print("Hierarchy for Built-in exceptions is : ")
inspect.getclasstree(inspect.getmro(BaseException))
  
tree_class(BaseException)
# Out:
# Hierarchy for Built-in exceptions is :
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- itimer_error
# --------- herror
# --------- gaierror
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %%
'''Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.
- ArithmeticErrors -> FloatingPointError, OverflowError, ZeroDivisionError'''

try:
    a=10
    a/0
except ArithmeticError as e:
    print(e)
# Out:
# division by zero

# %%
#overflowError

j = 5.0
try:
        for i in range(1, 1000):
            j = j**i
except ArithmeticError as e:
    print(e)
# Out:
# (34, 'Numerical result out of range')

# %%
'''Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.
- LookupError class is used when no keyword and Index is not found'''

x = [1,2,3,4,5]

try:
    print(x[6])
    
except LookupError as e:
    print(e)
# Out:
# list index out of range

# %%
try:
    a = {"class" : "data science" , "mobile_number": 120236548}
    print(a["key2"])
    
except KeyError as e:
    print(f"{e} , {e.__class__}")
# Out:
# 'key2' , <class 'KeyError'>

# %%
'''Q5. Explain ImportError. What is ModuleNotFoundError?'''
'''- It occurs when we try to import a module which is not available in buil-in module list '''

try:
    import himani
    a=10
except ImportError as e:
    print(f"{e}, {e.__class__}")
# Out:
# No module named 'himani', <class 'ModuleNotFoundError'>

# %%
'''Q6. List down some best practices for exception handling in python.'''
- always use specific exception 
- always use proper message
- always try to avoid multiple exception handling
- document all the errors.
